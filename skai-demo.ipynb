# %% [markdown]
# # Investigation of the 2020 Tennessee Outbreak

# %% [markdown]
# ## Introduction
#
# The first step to any model building, is the investigation of the training data.  For this exercise, we'll be investigating the data around the 2020 Tornado Outbreak which occurred March 2-3, 2020.  One of the five tornadoes in the Nashville area will be investigated.  Google Earth Engine (GEE) and Google Cloud Storage along with OCI's Alyce.ai module will be highlighted in this exploration.  Respectively, these are `ee`, `google.cloud`, and `skai.src.utils` modules.

# %% [markdown]
# ## Setup
#
# ### Environment
#
# For this Jupyter notebook to work, the user must set up the proper environment.  As the demonstration is being conducted in a Vertex AI instance, open Terminal and run the following lines:
#
# ```
# git clone https://github.com/lanzij-oci/skai.git
# pip install -r requirements.txt
# ```
#
# These steps will clone the github repo where all SKAI code is held and install the proper modules for this exercise.  Note, you should be using a Python 3 interpreter.

# %% [markdown]
# ### Authentication
#
# Setup Instructions were sent to participants prior to this session outlining registration to Google tools and Google Earth Engine.
#
# #### Google Cloud Tools Authentication
#
# Individuals will automatically have access to Google tools, e.g. Cloud Storage and BigQuery APIs, and saved resources, e.g. data layers and models, in this workshop's project `gee-workshop-042023`.  In general, users of the Vertex AI Jupyterlab notebook are automatically authenticated with Google.  The expectation is that participants will establish and manage their own google projects going forward.  As such, to authenticate with google resources outside of the Vertex AI platform, it is recommended that users leverage Google's Cloud [SDK](https://cloud.google.com/sdk).
#
# #### Google Earth Engine Authentication
#
# GEE authentication is easy.  Run the following line and follow the necessary steps:

# %%
# Import the google earth engine module and authenticate
import ee
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=4itU5REHj5ta6haKlSHv_N1PrMZMMRsn5nqMa6qpXdA&tc=y929161_TvapRID04AV9An8noAtHABQTCobMLReYD9A&cc=egfYNu211DUoO78beOUumcWOPTOcQQYkk1TjzWw_ZcE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=4itU5REHj5ta6haKlSHv_N1PrMZMMRsn5nqMa6qpXdA&tc=y929161_TvapRID04AV9An8noAtHABQTCobMLReYD9A&cc=egfYNu211DUoO78beOUumcWOPTOcQQYkk1TjzWw_ZcE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1Adeu5BWE17Ds-0zDNzhBodxIfR4dwHiYDg-GQW_fLKgJk0428IZ8B8MUA1w
# Successfully saved authorization token.

# %% [markdown]
# ## Investigation of Pre-Tornado Imagery with GEE
#
#
# For the SKAI model to be effective, high-resolution RGB images of the earth's surface are required before and after the disaster has taken place.  For this training session, images are sourced from GEE (before) and NOAA (after).  Attendees can access the the NOAA images from [here](https://storms.ngs.noaa.gov/storms/nashville/index.html#16/36.1778/-85.5808).  Documentation on the NAIP imagery can be found [here](https://developers.google.com/earth-engine/datasets/catalog/USDA_NAIP_DOQQ).
#
# Accessing and visualizing content from GEE [collection](https://developers.google.com/earth-engine/datasets) is highlighted in this section.  Analyses focus on the EF4 tornado that touched down near Cookville, TN.  As part of this section, usage of openstreet maps and visualizing a bounding box will also be highlighted.

# %% [markdown]
# ### Pulling and Visualizing GEE imagery

# %%
# Initializing GEE

ee.Initialize()

# %%
nashville_tornado_aoi = ee.Geometry.Polygon([[-87.02166525553643,36.23872528550273],[-87.01933354050459,36.07956369239288],[-85.4159305150307,36.0843353717099],[-85.41498797039785,36.24316124917394],[-87.02166525553643,36.23872528550273]])
tornado_5_aoi = ee.Geometry.Polygon([[-85.68105416273637,36.20591434435648],[-85.68156346863256,36.13942195686942],[-85.50291588726027,36.13839650921801],[-85.50225425962512,36.20487047284015],[-85.68105416273637,36.20591434435648]])

# nashville_tornado_aoi is the area of interest, AOI, corresponding to the region where five tornadoes tracked in the Nashville area
# tornado_5_aoi is the AOI correponding the to the EF4 tornado that will be analyzed in this notebook; subset of nashville_tornado_aoi

# %%
# Importing NAIP imagery from GEE

nashville_before = ee.ImageCollection('USDA/NAIP/DOQQ').filterDate('2018-01-01', '2020-02-29').filterBounds(nashville_tornado_aoi)

# %%
# Modules for mapping the images in GEE
import folium
from skai.src.utils import add_ee_layer

# Pulling the Openstreet map region where the five tornadoes around Nashville, TN
map = folium.Map(location=tornado_5_aoi.centroid().getInfo()['coordinates'][::-1],zoom_start=13)

# Adding the RGB NAIP layer to the base image
map.add_ee_layer(nashville_before.median(), {'bands': ['R', 'G', 'B'], 'min': 0, 'max': 255}, 'Nashville, TN Before')

#Displaying the map
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acf30be2cd3a7e395d00c36a1e7f9de2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acf30be2cd3a7e395d00c36a1e7f9de2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acf30be2cd3a7e395d00c36a1e7f9de2 = L.map(
#                 &quot;map_acf30be2cd3a7e395d00c36a1e7f9de2&quot;,
#                 {
#                     center: [36.17218407279123, -85.5919504098673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6840be286bf6856e30183dfe971aada = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#
#
#             var tile_layer_bb0c51c997c3e1529909475323c19640 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/2d3a557c024d65f6208ed0d12ab0f776-8fc7f501217ac65b003c515bb7f7f4fa/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 OCI | Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The region of Tennessee affected by tornadoes is quite large.  To demonstrate the effectiveness of SKAI, the path from one of the tornadoes was selected.  The following sections highlight where this is.

# %%
from shapely.geometry import Polygon

folium.GeoJson(Polygon(tornado_5_aoi.getInfo()['coordinates'][0]), 
               name='Tornado #5 - Cookeville, TN',
               style_function=lambda x:{'fillColor': '#FF0000', 'color': '#FF0000', 'fillOpacity': 0.0}).add_to(map)

map.add_child(folium.LayerControl())
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acf30be2cd3a7e395d00c36a1e7f9de2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acf30be2cd3a7e395d00c36a1e7f9de2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acf30be2cd3a7e395d00c36a1e7f9de2 = L.map(
#                 &quot;map_acf30be2cd3a7e395d00c36a1e7f9de2&quot;,
#                 {
#                     center: [36.17218407279123, -85.5919504098673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6840be286bf6856e30183dfe971aada = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#
#
#             var tile_layer_bb0c51c997c3e1529909475323c19640 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/2d3a557c024d65f6208ed0d12ab0f776-8fc7f501217ac65b003c515bb7f7f4fa/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 OCI | Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#
#
#         function geo_json_b7d32335c36fec62ea7a66eace529f8e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF0000&quot;, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.0};
#             }
#         }
#
#         function geo_json_b7d32335c36fec62ea7a66eace529f8e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b7d32335c36fec62ea7a66eace529f8e = L.geoJson(null, {
#                 onEachFeature: geo_json_b7d32335c36fec62ea7a66eace529f8e_onEachFeature,
#
#                 style: geo_json_b7d32335c36fec62ea7a66eace529f8e_styler,
#         });
#
#         function geo_json_b7d32335c36fec62ea7a66eace529f8e_add (data) {
#             geo_json_b7d32335c36fec62ea7a66eace529f8e
#                 .addData(data)
#                 .addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#         }
#             geo_json_b7d32335c36fec62ea7a66eace529f8e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-85.68105416273637, 36.20591434435648], [-85.68156346863256, 36.13942195686942], [-85.50291588726027, 36.13839650921801], [-85.50225425962512, 36.20487047284015], [-85.68105416273637, 36.20591434435648]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var layer_control_7c26e3b67ee9294b24461911f7952d9c = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d6840be286bf6856e30183dfe971aada,
#                 },
#                 overlays :  {
#                     &quot;Nashville, TN Before&quot; : tile_layer_bb0c51c997c3e1529909475323c19640,
#                     &quot;Tornado #5 - Cookeville, TN&quot; : geo_json_b7d32335c36fec62ea7a66eace529f8e,
#                 },
#             };
#             L.control.layers(
#                 layer_control_7c26e3b67ee9294b24461911f7952d9c.base_layers,
#                 layer_control_7c26e3b67ee9294b24461911f7952d9c.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_acf30be2cd3a7e395d00c36a1e7f9de2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### SKAI and Openstreet Maps
#
# The artificial intelligence behind SKAI requires the computer to recognize where buildings are.  Many building masks, the 'digitization of buildings,' are available through the OpenStreet Maps module `osmnx`.  However, Facebook's Segment Anythnig Model can be used to automatically identify more buildings or other infrastructure.
#
# In the next boxes of code, masks of buildings is demonstrated.

# %%
# Importing the OpenStreet Maps module
import osmnx as ox

# Pulling the polygons of the buildings in the tornado AOI
buildings = ox.features_from_polygon(Polygon(tornado_5_aoi.getInfo()['coordinates'][0]), tags={'building': True}) 
print(f'Total buildings in AOI: {len(buildings)}')
# Out:
# Total buildings in AOI: 9331

# %%
# Summarizing types of buildings in the tornado's pathway
buildings['building'].value_counts()
# Out:
# house                 6974
# apartments             800
# yes                    579
# barn                   552
# commercial             129
# retail                  78
# industrial              39
# garage                  36
# university              35
# semidetached_house      27
# dormitory               18
# school                  15
# terrace                 11
# church                   8
# roof                     6
# warehouse                5
# hospital                 4
# residential              4
# construction             3
# office                   2
# grandstands              2
# grandstand               2
# shed                     2
# Name: building, dtype: int64

# %%
# Pulling the Openstreet map region where the five tornadoes around Nashville, TN
map = folium.Map(location=tornado_5_aoi.centroid().getInfo()['coordinates'][::-1],zoom_start=13)

# Adding the RGB NAIP layer to the base image
map.add_ee_layer(nashville_before.median(), {'bands': ['R', 'G', 'B'], 'min': 0, 'max': 255}, 'Nashville, TN Before')

# Adding the AOI polygon to the map
folium.GeoJson(Polygon(tornado_5_aoi.getInfo()['coordinates'][0]), 
               name='Tornado #5 - Cookeville, TN',
               style_function=lambda x:{'fillColor': '#FF0000', 'color': '#FF0000', 'fillOpacity': 0.0}).add_to(map)

# Adding the building masks to the map
folium.GeoJson(buildings, 
              style_function=lambda x:{'fillColor': '#00FF00', 'color': '#00FF00', 'fillOpacity': 0.3},
              name='Buildings').add_to(map)

map.add_child(folium.LayerControl())
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44916f111de64fff1ddd57fbf17653e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44916f111de64fff1ddd57fbf17653e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44916f111de64fff1ddd57fbf17653e9 = L.map(
#                 &quot;map_44916f111de64fff1ddd57fbf17653e9&quot;,
#                 {
#                     center: [36.17218407279123, -85.5919504098673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a03a313ca5aa2c518dc86216f7d9a628 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44916f111de64fff1ddd57fbf17653e9);
#
#
#             var tile_layer_1add0347aa0c45e22c8fd715e101178a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/2d3a557c024d65f6208ed0d12ab0f776-3a08623576f89b45d07208b6fdd5c2e6/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 OCI | Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44916f111de64fff1ddd57fbf17653e9);
#
#
#         function geo_json_00d34e0e33b1f3e45699259640ed13cd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF0000&quot;, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.0};
#             }
#         }
#
#         function geo_json_00d34e0e33b1f3e45699259640ed13cd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_00d34e0e33b1f3e45699259640ed13cd = L.geoJson(null, {
#                 onEachFeature: geo_json_00d34e0e33b1f3e45699259640ed13cd_onEachFeature,
#
#                 style: geo_json_00d34e0e33b1f3e45699259640ed13cd_styler,
#         });
#
#         function geo_json_00d34e0e33b1f3e45699259640ed13cd_add (data) {
#             geo_json_00d34e0e33b1f3e45699259640ed13cd
#                 .addData(data)
#                 .addTo(map_44916f111de64fff1ddd57fbf17653e9);
#         }
#             geo_json_00d34e0e33b1f3e45699259640ed13cd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-85.68105416273637, 36.20591434435648], [-85.68156346863256, 36.13942195686942], [-85.50291588726027, 36.13839650921801], [-85.50225425962512, 36.20487047284015], [-85.68105416273637, 36.20591434435648]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var layer_control_489c3fe86a97e0a2f84ad84295018d64 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a03a313ca5aa2c518dc86216f7d9a628,
#                 },
#                 overlays :  {
#                     &quot;Nashville, TN Before&quot; : tile_layer_1add0347aa0c45e22c8fd715e101178a,
#                     &quot;Tornado #5 - Cookeville, TN&quot; : geo_json_00d34e0e33b1f3e45699259640ed13cd,
#                 },
#             };
#             L.control.layers(
#                 layer_control_489c3fe86a97e0a2f84ad84295018d64.base_layers,
#                 layer_control_489c3fe86a97e0a2f84ad84295018d64.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_44916f111de64fff1ddd57fbf17653e9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Investigation of Post-Tornado Imagery with Google Cloud Storage
#
#
# As stated above, NOAA images from [here](https://storms.ngs.noaa.gov/storms/nashville/index.html#16/36.1778/-85.5808).  They are pre-processed, high-resolution images that have alread been downloaded into a Cloud Storage bucket, `skai-tornado` in the Google Cloud Platform project, `gee-workshop-042023`.  Cloud Storage is a good place for users to store non-tabular, geospatial formats such as rasters.  Outside of this workshop, users will need to establish their own projects and buckets.

# %%
# Importing the Cloud module to import post-tornado images
from google.cloud import storage

# Instantiate a GCS client & List all GeoTIFF files in the bucket with the given prefix
storage_client = storage.Client()
blobs = storage_client.list_blobs('skai-tornado', prefix='nashville-images/cog/')
blob_list = [blob.name for blob in blobs if blob.name.endswith('.tif')]

blob_list
# Out:
# ['nashville-images/cog/20200307aC0852700w360900n.tif',
#  'nashville-images/cog/20200307aC0852700w361030n.tif',
#  'nashville-images/cog/20200307aC0852700w361200n.tif',
#  'nashville-images/cog/20200307aC0852830w360730n.tif',
#  'nashville-images/cog/20200307aC0852830w360900n.tif',
#  'nashville-images/cog/20200307aC0852830w361030n.tif',
#  'nashville-images/cog/20200307aC0852830w361200n.tif',
#  'nashville-images/cog/20200307aC0853000w360730n.tif',
#  'nashville-images/cog/20200307aC0853000w360900n.tif',
#  'nashville-images/cog/20200307aC0853000w361030n.tif',
#  'nashville-images/cog/20200307aC0853000w361200n.tif',
#  'nashville-images/cog/20200307aC0853130w360900n.tif',
#  'nashville-images/cog/20200307aC0853130w361030n.tif',
#  'nashville-images/cog/20200307aC0853130w361200n.tif',
#  'nashville-images/cog/20200307aC0853300w361030n.tif',
#  'nashville-images/cog/20200307aC0853300w361200n.tif',
#  'nashville-images/cog/20200307aC0853430w361030n.tif',
#  'nashville-images/cog/20200307aC0853430w361200n.tif',
#  'nashville-images/cog/20200307aC0853600w361030n.tif',
#  'nashville-images/cog/20200307aC0853600w361200n.tif',
#  'nashville-images/cog/20200307aC0853730w361030n.tif',
#  'nashville-images/cog/20200307aC0853730w361200n.tif',
#  'nashville-images/cog/20200307aC0853900w361030n.tif',
#  'nashville-images/cog/20200307aC0853900w361200n.tif',
#  'nashville-images/cog/20200307aC0854030w361030n.tif',
#  'nashville-images/cog/20200307aC0854030w361200n.tif',
#  'nashville-images/cog/20200307aC0854200w361030n.tif',
#  'nashville-images/cog/20200307aC0854200w361200n.tif',
#  'nashville-images/cog/20200307aC0854330w361030n.tif',
#  'nashville-images/cog/20200307aC0854330w361200n.tif',
#  'nashville-images/cog/20200307aC0854500w361030n.tif',
#  'nashville-images/cog/20200307aC0854500w361200n.tif',
#  'nashville-images/cog/20200307aC0854630w360900n.tif',
#  'nashville-images/cog/20200307aC0854630w361030n.tif',
#  'nashville-images/cog/20200307aC0854630w361200n.tif',
#  'nashville-images/cog/20200307aC0854800w360900n.tif',
#  'nashville-images/cog/20200307aC0854800w361030n.tif',
#  'nashville-images/cog/20200307aC0854800w361200n.tif',
#  'nashville-images/cog/20200307aC0854930w360900n.tif',
#  'nashville-images/cog/20200307aC0854930w361030n.tif',
#  'nashville-images/cog/20200307aC0854930w361200n.tif',
#  'nashville-images/cog/20200307aC0855100w360900n.tif',
#  'nashville-images/cog/20200307aC0855100w361030n.tif',
#  'nashville-images/cog/20200307aC0855230w360900n.tif',
#  'nashville-images/cog/20200307aC0855230w361030n.tif',
#  'nashville-images/cog/20200307aC0855400w360900n.tif',
#  'nashville-images/cog/20200307aC0855400w361030n.tif',
#  'nashville-images/cog/20200307aC0855530w360900n.tif',
#  'nashville-images/cog/20200307aC0855530w361030n.tif',
#  'nashville-images/cog/20200307aC0855700w360900n.tif',
#  'nashville-images/cog/20200307aC0855700w361030n.tif',
#  'nashville-images/cog/20200307aC0855700w361200n.tif',
#  'nashville-images/cog/20200307aC0855830w360900n.tif',
#  'nashville-images/cog/20200307aC0855830w361030n.tif',
#  'nashville-images/cog/20200307aC0855830w361200n.tif',
#  'nashville-images/cog/20200307aC0860000w360900n.tif',
#  'nashville-images/cog/20200307aC0860000w361030n.tif',
#  'nashville-images/cog/20200307aC0860000w361200n.tif',
#  'nashville-images/cog/20200307aC0860130w360900n.tif',
#  'nashville-images/cog/20200307aC0860130w361030n.tif',
#  'nashville-images/cog/20200307aC0860130w361200n.tif',
#  'nashville-images/cog/20200307aC0860300w361030n.tif',
#  'nashville-images/cog/20200307aC0860300w361200n.tif',
#  'nashville-images/cog/20200307aC0860430w361030n.tif',
#  'nashville-images/cog/20200307aC0860430w361200n.tif',
#  'nashville-images/cog/20200307aC0860600w361030n.tif',
#  'nashville-images/cog/20200307aC0860600w361200n.tif',
#  'nashville-images/cog/20200307aC0860730w361030n.tif',
#  'nashville-images/cog/20200307aC0860730w361200n.tif',
#  'nashville-images/cog/20200307aC0860900w361030n.tif',
#  'nashville-images/cog/20200307aC0860900w361200n.tif',
#  'nashville-images/cog/20200307aC0861030w361030n.tif',
#  'nashville-images/cog/20200307aC0861030w361200n.tif',
#  'nashville-images/cog/20200307aC0861200w361030n.tif',
#  'nashville-images/cog/20200307aC0861200w361200n.tif',
#  'nashville-images/cog/20200307aC0861200w361330n.tif',
#  'nashville-images/cog/20200307aC0861330w361030n.tif',
#  'nashville-images/cog/20200307aC0861330w361200n.tif',
#  'nashville-images/cog/20200307aC0861330w361330n.tif',
#  'nashville-images/cog/20200307aC0861500w361030n.tif',
#  'nashville-images/cog/20200307aC0861500w361200n.tif',
#  'nashville-images/cog/20200307aC0861500w361330n.tif',
#  'nashville-images/cog/20200307aC0861630w361030n.tif',
#  'nashville-images/cog/20200307aC0861630w361200n.tif',
#  'nashville-images/cog/20200307aC0861630w361330n.tif',
#  'nashville-images/cog/20200307aC0861800w361030n.tif',
#  'nashville-images/cog/20200307aC0861800w361200n.tif',
#  'nashville-images/cog/20200307aC0861800w361330n.tif',
#  'nashville-images/cog/20200307aC0861930w361030n.tif',
#  'nashville-images/cog/20200307aC0861930w361200n.tif',
#  'nashville-images/cog/20200307aC0861930w361330n.tif',
#  'nashville-images/cog/20200307aC0862100w361030n.tif',
#  'nashville-images/cog/20200307aC0862100w361200n.tif',
#  'nashville-images/cog/20200307aC0862100w361330n.tif',
#  'nashville-images/cog/20200307aC0862230w361030n.tif',
#  'nashville-images/cog/20200307aC0862230w361200n.tif',
#  'nashville-images/cog/20200307aC0862230w361330n.tif',
#  'nashville-images/cog/20200307aC0862400w361030n.tif',
#  'nashville-images/cog/20200307aC0862400w361200n.tif',
#  'nashville-images/cog/20200307aC0862400w361330n.tif',
#  'nashville-images/cog/20200307aC0862530w361030n.tif',
#  'nashville-images/cog/20200307aC0862530w361200n.tif',
#  'nashville-images/cog/20200307aC0862530w361330n.tif',
#  'nashville-images/cog/20200307aC0862700w361030n.tif',
#  'nashville-images/cog/20200307aC0862700w361200n.tif',
#  'nashville-images/cog/20200307aC0862700w361330n.tif',
#  'nashville-images/cog/20200307aC0862830w361030n.tif',
#  'nashville-images/cog/20200307aC0862830w361200n.tif',
#  'nashville-images/cog/20200307aC0862830w361330n.tif',
#  'nashville-images/cog/20200307aC0863000w361030n.tif',
#  'nashville-images/cog/20200307aC0863000w361330n.tif',
#  'nashville-images/cog/20200307aC0863130w361030n.tif',
#  'nashville-images/cog/20200307aC0863130w361200n.tif',
#  'nashville-images/cog/20200307aC0863130w361330n.tif',
#  'nashville-images/cog/20200307aC0863300w361030n.tif',
#  'nashville-images/cog/20200307aC0863300w361200n.tif',
#  'nashville-images/cog/20200307aC0863300w361330n.tif',
#  'nashville-images/cog/20200307aC0863430w361030n.tif',
#  'nashville-images/cog/20200307aC0863430w361200n.tif',
#  'nashville-images/cog/20200307aC0863430w361330n.tif',
#  'nashville-images/cog/20200307aC0863600w361030n.tif',
#  'nashville-images/cog/20200307aC0863600w361200n.tif',
#  'nashville-images/cog/20200307aC0863600w361330n.tif',
#  'nashville-images/cog/20200307aC0863730w361030n.tif',
#  'nashville-images/cog/20200307aC0863730w361200n.tif',
#  'nashville-images/cog/20200307aC0863730w361330n.tif',
#  'nashville-images/cog/20200307aC0863900w361030n.tif',
#  'nashville-images/cog/20200307aC0863900w361200n.tif',
#  'nashville-images/cog/20200307aC0863900w361330n.tif',
#  'nashville-images/cog/20200307aC0864030w361030n.tif',
#  'nashville-images/cog/20200307aC0864030w361200n.tif',
#  'nashville-images/cog/20200307aC0864030w361330n.tif',
#  'nashville-images/cog/20200307aC0864200w361030n.tif',
#  'nashville-images/cog/20200307aC0864200w361200n.tif',
#  'nashville-images/cog/20200307aC0864330w361030n.tif',
#  'nashville-images/cog/20200307aC0864330w361200n.tif',
#  'nashville-images/cog/20200307aC0864500w361030n.tif',
#  'nashville-images/cog/20200307aC0864500w361200n.tif',
#  'nashville-images/cog/20200307aC0864630w361030n.tif',
#  'nashville-images/cog/20200307aC0864630w361200n.tif',
#  'nashville-images/cog/20200307aC0864800w361030n.tif',
#  'nashville-images/cog/20200307aC0864800w361200n.tif',
#  'nashville-images/cog/20200307aC0864930w361030n.tif',
#  'nashville-images/cog/20200307aC0864930w361200n.tif',
#  'nashville-images/cog/20200307aC0865100w361030n.tif',
#  'nashville-images/cog/20200307aC0865100w361200n.tif',
#  'nashville-images/cog/20200307aC0865230w361030n.tif',
#  'nashville-images/cog/20200307aC0865230w361200n.tif',
#  'nashville-images/cog/20200307aC0865400w361030n.tif',
#  'nashville-images/cog/20200307aC0865400w361200n.tif',
#  'nashville-images/cog/20200307aC0865530w360900n.tif',
#  'nashville-images/cog/20200307aC0865530w361030n.tif',
#  'nashville-images/cog/20200307aC0865530w361200n.tif',
#  'nashville-images/cog/20200307aC0865700w360900n.tif',
#  'nashville-images/cog/20200307aC0865700w361030n.tif',
#  'nashville-images/cog/20200307aC0865700w361200n.tif',
#  'nashville-images/cog/20200307aC0865830w360900n.tif',
#  'nashville-images/cog/20200307aC0865830w361030n.tif',
#  'nashville-images/cog/20200307aC0865830w361200n.tif',
#  'nashville-images/cog/20200307aC0870000w361030n.tif',
#  'nashville-images/cog/20200307aC0870000w361200n.tif',
#  'nashville-images/cog/20200307aC0870130w361200n.tif']

# %% [markdown]
# The AOI was mosaicked into many raster files.  GEE can easily piece these tifs back into a single image.

# %%
# Creating an ImageCollection in EE of the post-tornado RGB image from NOAA
nashville_after = ee.ImageCollection.fromImages([ee.Image.loadGeoTIFF(f'gs://skai-tornado/{path}') for path in blob_list])

# %% [markdown]
# For this workshop, we place all of the partitions in the `skai-tornado` bucket.

# %%
# Mapping the post-tornado images

# Pulling the Openstreet map region where the five tornadoes around Nashville, TN
map = folium.Map(location=tornado_5_aoi.centroid().getInfo()['coordinates'][::-1],zoom_start=13)

# Adding the post-tornado RGB images
map.add_ee_layer(nashville_after.median(), {'bands': ['B2', 'B1', 'B0'], 'min': 0, 'max': 255}, 'Nashville, TN After')

# Adding the AOI polygon to the map
folium.GeoJson(Polygon(tornado_5_aoi.getInfo()['coordinates'][0]), 
               name='Tornado #5 - Cookeville, TN',
               style_function=lambda x:{'fillColor': '#FF0000', 'color': '#FF0000', 'fillOpacity': 0.0}).add_to(map)

# Adding the building masks to the map
folium.GeoJson(buildings, 
              style_function=lambda x:{'fillColor': '#00FF00', 'color': '#00FF00', 'fillOpacity': 0.3},
              name='Buildings').add_to(map)

map.add_child(folium.LayerControl())
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8a1c1fcc580f7973a505fd91f9d9f63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8a1c1fcc580f7973a505fd91f9d9f63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8a1c1fcc580f7973a505fd91f9d9f63 = L.map(
#                 &quot;map_a8a1c1fcc580f7973a505fd91f9d9f63&quot;,
#                 {
#                     center: [36.17218407279123, -85.5919504098673],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd78386488e94a7a129c91c2b95951cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a1c1fcc580f7973a505fd91f9d9f63);
#
#
#             var tile_layer_56c4b2e7169901f6317227f9a85e9bcf = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/757bb936a5a9f52c9e313f6f182fb8f8-dbcf7f2cc53bb51f07ee8cfcc3bf4c22/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u00a9 OCI | Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a1c1fcc580f7973a505fd91f9d9f63);
#
#
#         function geo_json_9c568dcebca990d7a762fd27cadd7cd1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF0000&quot;, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.0};
#             }
#         }
#
#         function geo_json_9c568dcebca990d7a762fd27cadd7cd1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9c568dcebca990d7a762fd27cadd7cd1 = L.geoJson(null, {
#                 onEachFeature: geo_json_9c568dcebca990d7a762fd27cadd7cd1_onEachFeature,
#
#                 style: geo_json_9c568dcebca990d7a762fd27cadd7cd1_styler,
#         });
#
#         function geo_json_9c568dcebca990d7a762fd27cadd7cd1_add (data) {
#             geo_json_9c568dcebca990d7a762fd27cadd7cd1
#                 .addData(data)
#                 .addTo(map_a8a1c1fcc580f7973a505fd91f9d9f63);
#         }
#             geo_json_9c568dcebca990d7a762fd27cadd7cd1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-85.68105416273637, 36.20591434435648], [-85.68156346863256, 36.13942195686942], [-85.50291588726027, 36.13839650921801], [-85.50225425962512, 36.20487047284015], [-85.68105416273637, 36.20591434435648]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             var layer_control_d5e8b10123668156fc60b4d6578a4acc = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cd78386488e94a7a129c91c2b95951cb,
#                 },
#                 overlays :  {
#                     &quot;Nashville, TN After&quot; : tile_layer_56c4b2e7169901f6317227f9a85e9bcf,
#                     &quot;Tornado #5 - Cookeville, TN&quot; : geo_json_9c568dcebca990d7a762fd27cadd7cd1,
#                 },
#             };
#             L.control.layers(
#                 layer_control_d5e8b10123668156fc60b4d6578a4acc.base_layers,
#                 layer_control_d5e8b10123668156fc60b4d6578a4acc.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a8a1c1fcc580f7973a505fd91f9d9f63);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# With the OpenStreet Map building masks, we can see the devastation of this tornado.

# %% [markdown]
# ## Model Training
#
# Vertex AI was leveraged in the development of the SKAI model.  [This link](https://github.com/google-research/skai/blob/main/docs/README.md) has instructions of how to develop SKAI for other disasters.  Labelling for this exercise has been completed, and users can access the [interactive labelling process](https://console.cloud.google.com/vertex-ai/locations/us-central1/datasets/8509901140614184960;annotationSetId=985173413603573760/browse?project=gee-workshop-042023).  Subject matter experts typically identify and categorize the severity of damaged buildings.
#
# For the workshop, the Tornado-SKAI model has been built and can be accessed here: `gs://skai-tornado/models/tornado/checkpoints/model.ckpt-00200000`.  When applying the model to new tornado disasters, this is the code:

# %%
from skai.src.utils import run_command
from google.auth import default

# Get the values from environment variables
credentials, project_id = default()
cloud_region = 'us-central1'

# Set the other parameters
params = {
    'project': project_id,
    'location': cloud_region,
    'job_type': 'eval',
    'display_name': 'skai_nashville',                                                                  # change name for costume job
    'eval_docker_image_uri_path': 'gcr.io/disaster-assessment/ssl-eval-uri',
    'service_account': 'skai-427@gee-workshop-042023.iam.gserviceaccount.com',
    'dataset_name': 'skai-nashville',
    'train_dir': 'gs://skai-tornado/models/tornado-nashville/',                                       # change for train dir for predictions -> output at skai-demo/models/refinery_model/predictions/
    'test_examples': 'gs://skai-tornado/nashville/examples/labeled_nashville_buildings.tfrecord',     # change to unlabled data set -- generated above
    'inference_mode': 'True',
    'save_predictions': 'True',
    'eval_ckpt': 'gs://skai-tornado/models/tornado-nashville/checkpoints/model.ckpt-00200384',        # use specific model, not all the model
}

# Generate predictions using params
run_command("src/launch_vertex_job.py",**params)

# %% [markdown]
# A TensorFlow environment will need to be spun up for the generation of predictions.
